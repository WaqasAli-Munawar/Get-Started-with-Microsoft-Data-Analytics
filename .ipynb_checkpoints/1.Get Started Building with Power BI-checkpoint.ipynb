# %% [markdown]
# Microsoft Power BI is a collection of software services, apps, and connectors that work together to **turn our unrelated sources of data into coherent**, visually immersive, and interactive insights. Whether our data is a simple Microsoft Excel workbook or a collection of cloud-based and on-premises hybrid data warehouses, Power BI lets us easily connect to our data sources, visualize (or discover) what's important, and share our findings.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Power BI can be simple and fast — it can deliver quick insights from an Excel workbook or a local database. But Power BI is also robust and enterprise-grade, ready not only for extensive modeling and real-time analytics but also for custom development. Therefore, it can be our personal report and visualization tool, but it can also serve as the analytics and decision engine behind group projects, divisions, or entire corporations.

# %% [markdown]
# Power BI consists of a Microsoft Windows desktop application called **Power BI Desktop**, an online SaaS (Software as a Service) called the **Power BI service**, and **mobile Power BI apps** that are available on any device, with native mobile BI apps for Windows, iOS, and Android.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# These three elements — desktop, the service, and mobile apps — enable us to create, share, and consume business insights however it serves us most effectively.
#
# * **Power BI Desktop**: We can download **Power BI Desktop** from the [web](https://go.microsoft.com/fwlink/?LinkID=521662) or as an [app from the Microsoft Store](https://aka.ms/pbidesktopstore) on the Windows tab.
#
# * **Power BI service**: Before we can **sign in** to Power BI, we'll need an account. To get a free trial, go to [app.powerbi.com](https://go.microsoft.com/fwlink/?linkid=2101313) and sign up with our work email address. For detailed steps on setting up an account, see [Sign in to Power BI service](https://docs.microsoft.com/en-us/power-bi/consumer/end-user-sign-in).

# %% [markdown]
# Note that **we do not need to download Power BI Desktop** or create a free trial account right now. We can learn Power BI directly from the browser! We'll learn how to create free trial account in a later file when we begin working with the Power BI Service.
#
# A common **workflow in Power BI** begins in Power BI Desktop, by creating a report. That report is then published to the Power BI service and finally shared, so that users of Power BI Mobile apps can consume the information.
#
# It doesn't always happen that way, and that's okay. But we'll use that flow to explore the different parts of Power BI and how they complement each other.
#
# Okay, now that we have an overview and what Power BI is (and its three main elements), let's look at what it's like to use Power BI.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# The Power BI activities and analyses that we'll learn generally follow a common flow. It looks like this:
#
# * Bring data into Power BI Desktop, and create a report.
# * Publish to the Power BI service, where we can create new visualizations or build dashboards.
# * Share dashboards with others, especially people who are on the go.
# * View and interact with shared dashboards and reports in Power BI Mobile apps.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# We might spend all our time in the Power BI service, reviewing visuals and reports created by others. And that's fine. Someone else on our team might spend their time in Power BI Desktop, which is fine too. To help us understand the full continuum of Power BI and what it can do, we'll show all the possibilities, then we can decide how to best use it to our advantage.
#
# So, let's dive in! Our first order of business is to learn the basic building blocks of Power BI, which will provide a solid basis for turning data into useful reports and visuals.

# %% [markdown]
# Everything we do in Microsoft Power BI breaks down into a few basic **building blocks**. After we understand these building blocks, we can expand on each of them and begin creating elaborate and complex reports. After all, even seemingly complex things are built from basic building blocks.
#
# For example, we create buildings with wood, steel, concrete and glass, and we create cars from metal, fabric, and rubber. Of course, buildings and cars can also be basic or elaborate, depending on the arrangements of those basic building blocks.

# %% [markdown]
# Let's look at these basic building blocks, discuss some simple things that we can build with them, and then examine how we can also create complex things.
#
# Here are the basic building blocks in Power BI:
#
# * Visualizations
# * Datasets
# * Reports
# * Dashboards
# * Tiles

# %% [markdown]
# A **visualization** (sometimes also referred to as a visual) is a visual representation of data, like a chart, a color-coded map, or other interesting graphical displays we can create to represent our data.
#
# Power BI includes all sorts of visualizations, and more are coming all the time. The following image shows a collection of different visualizations created in Power BI:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Visualizations can be simple, like a single number that represents something significant, or they can be visually complex, like a gradient-colored map that shows voter sentiment about a certain social issue or concern. The goal of a visual is to present data in a way that provides context and insights, both of which would probably be difficult to discern from a raw table of numbers or text.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Following exercise will use the **Sales and Marketing Sample** data provided by Microsoft.
#
# 1. Access this data by navigating to the **File** tab of the Power BI interface. Click on the **Open Report** link, then click **Browse reports**, and select the **Sales and Marketing Sample PBIX** to load it.
#
#     * We may need to navigate to **This PC > Home** Folder to see the available reports.
#
#
# 2. Click on the **Market Share** tab at the bottom of the page.
#
#     * Hover over the bars of the **Total Units by Month and isVanArsdel** chart (the bottom graphic on the page).
#     * We can scroll horizontally if we don't see the entire chart.
#
#
# 3. Use this information to answer the following questions.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# A **dataset** is a collection of data that Power BI uses to create its visualizations.
#
# We can have a simple dataset that's based on a single table from a **Microsoft Excel workbook**, similar to what we see in the following image.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Datasets can also be a combination of many different sources, which we can filter and combine to create a unique collection of data (a dataset) to use in Power BI.
#
# For example, we can create a dataset from three different data sources,
# * one website table,
# * an Excel table, and
# * online results of an email marketing campaign.
#
# That unique combination is still considered a single dataset, even though it comes from many different sources.

# %% [markdown]
# Filtering data before bringing it into Power BI, lets we focus on the data that matters to us. For example, we can filter our contact database so that only customers who received emails from the marketing campaign are included in the dataset. We can then create visuals based on that subset (the filtered collection) of customers who were included in the campaign. Filtering helps us focus our data — and our efforts.

# %% [markdown]
# An important and enabling part of Power BI is its multitude of data **connectors**. Whether the data we want is in Excel or a Microsoft SQL Server database; in Azure or Oracle; or in a service like Facebook, Salesforce, or MailChimp, **Power BI has built-in data connectors that let us easily connect to that data, filter it if necessary, and bring it into our dataset**.
#
# After we have a dataset, we can begin creating visualizations that show different portions of it in different ways — and gain insights based on what we see. That's where reports come in.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Answer
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# In Power BI, a **report** is a collection of visualizations that appear together on one or more pages. Just like any other report you might create for a sales presentation or write for a school assignment, a report in Power BI is a collection of interrelated items.

# %% [markdown]
# The following image shows a report in Power BI Desktop. There are five **pages**:
#
# * Info
# * New Hires (this is the current page)
# * Actives and Separations
# * Bad Hires
# * New Hires Scorecard
#
# ![image.png](attachment:image.png)

# %% [markdown]
# We can also create reports in the Power BI service.
#
# Reports let us create many visualizations, on multiple pages if necessary, and they let us arrange those visualizations in whatever way best tells our story.
#
# We might have a report about quarterly sales, product growth in a particular segment, or migration patterns of polar bears. Whatever our subject, reports let us gather and organize our visualizations onto one page (or more).

# %% [markdown]
# When we're ready to share a report, or a collection of visualizations, we create a **dashboard**. A Power BI dashboard is a collection of visuals from a single page that we can share with others. Often, it's a selected group of visuals that provide quick insight into the data or story we're trying to present.
#
# A dashboard must fit on a single page, often called a canvas (the canvas is the blank backdrop in Power BI Desktop — or the service — where we put visualizations). Think of it like the canvas that an artist or painter uses — a workspace where we create, combine, and rework interesting and compelling visuals.

# %% [markdown]
# We can share dashboards with other users or groups, who can then interact with our dashboards when they're in the Power BI service or on their mobile device.
#
# In Power BI, a **tile** is a single visualization on a dashboard. It's the rectangular box that holds an individual visual. In the following image, we see one tile surrounded by other tiles.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# When we're creating a dashboard in Power BI, we can move or arrange tiles however we want. We can make them bigger, change their height or width, and snuggle them up to other tiles.
#
# When we're viewing, or consuming, a dashboard or report — which means we're not the creator or owner, but the report or dashboard has been shared with us — we can interact with it, but we can't change the size of the tiles or their arrangement.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Now that we've learned about the basic building blocks of Power BI, it should be clear that we can create datasets that make sense to us and create visually compelling reports that tell our story. Stories told with Power BI don't have to be complex, or complicated, to be compelling.
#
# For some people, using a single Excel table in a dataset and then sharing a dashboard with their team will be an incredibly valuable way to use Power BI.
#
# For others, the value of Power BI will be in using real-time Azure SQL Data Warehouse tables that combine with other databases and real-time sources to build a moment-by-moment dataset.
#
# For both groups, the process is the same: create datasets, build compelling visuals, and share them with others. And the result is also the same for both groups: harness our ever-expanding world of data, and turn it into actionable insights.
#
# Whether our data insights require straightforward or complex datasets, Power BI helps us get started quickly and can expand with our needs to be as complex as our data requires.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Let's do a quick review of what we covered in this module.
#
# * Microsoft Power BI is a collection of software services, apps, and connectors that work together to turn our data into interactive insights.
# * We can use data from single basic sources, like a Microsoft Excel workbook, or pull in data from multiple databases and cloud sources to create complex datasets and reports.
# * Power BI can be as straightforward as we want or as enterprise-ready as our complex global business requires.
# * Power BI consists of three main elements: These work together to let us create, interact with, share, and consume our data however we want.
#     * Power BI Desktop,
#     * the Power BI service, and
#     * Power BI Mobile.
#     ![image.png](attachment:image.png)

# %% [markdown]
# We also discussed the basic building blocks of Power BI:
#
# * **Visualizations** – Visual representations of data, sometimes just called visuals
# * **Datasets** – Collections of data that Power BI uses to create visualizations
# * **Reports** – Collections of visuals from datasets, spanning one or more pages
# * **Dashboards** – Single-page collections of visuals built from reports
# * **Tiles** – Single visualizations on a report or dashboard

# %% [markdown]
# We mentioned this before, but it's worth restating: this learning path builds our knowledge by following the common Power BI workflow:
#
# * Bring data into Power BI Desktop, and create a report
# * Publish to the Power BI service, where we create new visualizations or build dashboards
# * Share our dashboards with others, especially people who are on the go
# * View and interact with shared dashboards and reports in Power BI Mobile apps
#
# ![image.png](attachment:image.png)

# %% [markdown]
# We might not do all that work ourself — some people will only view dashboards created by someone else, and they'll just use the service. That's fine, and we'll show in another file how we can easily navigate and use the Power BI service to view and interact with reports and apps.
#
# But the next file follows the Power BI workflow, showing us how to create a report and publish it to the Power BI service. We'll learn how those reports and dashboards are created and how they connect to the data. We might even decide to create a report or dashboard of our own.
